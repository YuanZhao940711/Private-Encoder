# %%
from google.colab import drive
drive.mount('/content/drive')

import os 
os.chdir('/content/drive/My Drive/pSp_self_customize')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/pSp_self_customize

# %%
# Calculating FID value between original images with pSp output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq0k_5k ./image_datasets/inference_results
#FID:  55.139676800491685
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq0k_5k', './image_datasets/inference_results'])
# loading images from dir: image_datasets/ffhq0k_5k
# 100% 100/100 [28:44<00:00, 17.24s/it]
# loading images from dir: image_datasets/inference_results
# 100% 100/100 [28:32<00:00, 17.13s/it]
# FID:  55.139676800491685

# %%
# Calculating FID value between original images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq0k_5k ./image_datasets/blurred_images
#FID:  28.350567068836142
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq0k_5k', './image_datasets/blurred_images'])
# loading images from dir: image_datasets/ffhq0k_5k
# 100% 100/100 [29:19<00:00, 17.59s/it]
# loading images from dir: image_datasets/blurred_images
# 100% 100/100 [28:49<00:00, 17.29s/it]
# FID:  29.349810661604522

# %%
# Calculating FID value between original images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq0k_5k ./image_datasets/mosaiced_images
#FID:  40.54917724457505
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq0k_5k', './image_datasets/mosaiced_images'])
# loading images from dir: image_datasets/ffhq0k_5k
# 100% 100/100 [29:15<00:00, 17.55s/it]
# loading images from dir: image_datasets/mosaiced_images
# 100% 100/100 [29:09<00:00, 17.49s/it]
# FID:  40.54917017189257
