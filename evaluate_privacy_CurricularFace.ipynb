# %%
from google.colab import drive
drive.mount('/content/drive')

import os 
os.chdir('/content/drive/My Drive/pSp_PrivacyEncoder')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/pSp_PrivacyEncoder
# Out:
# /content

# %% [markdown]
# # DeepPrivacy
# #### Calculating ID similarity value between original images with DeepPrivacy output images
#
# *   ***ID similarity: 0.09+-0.10***

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=/content/drive/MyDrive/Image_datasets/celeba_align_20k_21k_aligned \
--gt_path=./image_datasets/DeepPrivacy_celeba_20k_21k_output/generated \
--id_threhold=0.19

##The ID similarity between original and CIAGAN Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is /content/drive/MyDrive/Image_datasets/inference_metricsaligned
# Running on 976 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 976 images
# ForkPoolWorker-1 done with 100/976
# ForkPoolWorker-1 done with 200/976
# ForkPoolWorker-1 done with 300/976
# ForkPoolWorker-1 done with 400/976
# ForkPoolWorker-1 done with 500/976
# ForkPoolWorker-1 done with 600/976
# ForkPoolWorker-1 done with 700/976
# ForkPoolWorker-1 done with 800/976
# ForkPoolWorker-1 done with 900/976
# New Average score is 0.09+-0.10
# Number of different identity is 856
# Different percent is 0.88
# Mischief managed in 1070.3339610099792s

# %% [markdown]
# # CIAGAN
# #### Calculating ID similarity value between original images with CIAGAN output images
#
# *   ***ID similarity: 0.20+-0.10***

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/CIAGAN_celeba_20k_21k_output/original \
--gt_path=./image_datasets/CIAGAN_celeba_20k_21k_output/generated \
--id_threhold=0.19

##The ID similarity between original and CIAGAN Output Images is: 0.20+-0.10
#Different percent is : 0.50
# Out:
# The inference metrics output path is ./image_datasets/CIAGAN_celeba_20k_21k_output/inference_metricsoriginal
# Running on 976 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 976 images
# ForkPoolWorker-1 done with 100/976
# ForkPoolWorker-1 done with 200/976
# ForkPoolWorker-1 done with 300/976
# ForkPoolWorker-1 done with 400/976
# ForkPoolWorker-1 done with 500/976
# ForkPoolWorker-1 done with 600/976
# ForkPoolWorker-1 done with 700/976
# ForkPoolWorker-1 done with 800/976
# ForkPoolWorker-1 done with 900/976
# New Average score is 0.20+-0.10
# Number of different identity is 489
# Different percent is 0.50
# Mischief managed in 1023.6093890666962s

# %% [markdown]
# # Inference CelebA
# #### Calculating ID similarity value between original images with inferenced output images
#
# *   Privacy 0.0 ID similarity:
# *   Privacy 0.1 ID similarity:
# *   Privacy 0.2 ID similarity: 0.19+-0.07
# *   Privacy 0.3 ID similarity:
# *   Privacy 0.4 ID similarity:
# *   Privacy 0.5 ID similarity:
# *   Privacy 0.6 ID similarity:
# *   Privacy 0.7 ID similarity:
# *   Privacy 0.8 ID similarity:
# *   Privacy 0.9 ID similarity:
# *   Privacy 1.0 ID similarity:

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.0/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.0/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.0/inference_metricsoriginal
# Running on 999 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 999 images
# ForkPoolWorker-1 done with 100/999
# ForkPoolWorker-1 done with 200/999
# ForkPoolWorker-1 done with 300/999
# ForkPoolWorker-1 done with 400/999
# ForkPoolWorker-1 done with 500/999
# ForkPoolWorker-1 done with 600/999
# ForkPoolWorker-1 done with 700/999
# ForkPoolWorker-1 done with 800/999
# ForkPoolWorker-1 done with 900/999
# New Average score is 0.11+-0.09
# Number of different identity is 817
# Different percent is 0.82
# Mischief managed in 1212.4079775810242s

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.1/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.1/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.1/inference_metricsoriginal
# Running on 1000 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 1000 images
# ForkPoolWorker-1 done with 100/1000
# ForkPoolWorker-1 done with 200/1000
# ForkPoolWorker-1 done with 300/1000
# ForkPoolWorker-1 done with 400/1000
# ForkPoolWorker-1 done with 500/1000
# ForkPoolWorker-1 done with 600/1000
# ForkPoolWorker-1 done with 700/1000
# ForkPoolWorker-1 done with 800/1000
# ForkPoolWorker-1 done with 900/1000
# ForkPoolWorker-1 done with 1000/1000
# New Average score is 0.17+-0.09
# Number of different identity is 612
# Different percent is 0.61
# Mischief managed in 981.5583562850952s

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.2/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.2/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.2/inference_metricsoriginal
# Running on 976 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 976 images
# ForkPoolWorker-1 done with 100/976
# ForkPoolWorker-1 done with 200/976
# ForkPoolWorker-1 done with 300/976
# ForkPoolWorker-1 done with 400/976
# ForkPoolWorker-1 done with 500/976
# ForkPoolWorker-1 done with 600/976
# ForkPoolWorker-1 done with 700/976
# ForkPoolWorker-1 done with 800/976
# ForkPoolWorker-1 done with 900/976
# New Average score is 0.19+-0.07
# Number of different identity is 490
# Different percent is 0.50
# Mischief managed in 978.4105980396271s

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.3/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.3/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.3/inference_metricsoriginal
# Running on 1000 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 1000 images
# ForkPoolWorker-1 done with 100/1000
# ForkPoolWorker-1 done with 200/1000
# ForkPoolWorker-1 done with 300/1000
# ForkPoolWorker-1 done with 400/1000
# ForkPoolWorker-1 done with 500/1000
# ForkPoolWorker-1 done with 600/1000
# ForkPoolWorker-1 done with 700/1000
# ForkPoolWorker-1 done with 800/1000
# ForkPoolWorker-1 done with 900/1000
# ForkPoolWorker-1 done with 1000/1000
# New Average score is 0.27+-0.10
# Number of different identity is 194
# Different percent is 0.19
# Mischief managed in 965.4243030548096s

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.4/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.4/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.4/inference_metricsoriginal
# Running on 1000 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 1000 images
# ForkPoolWorker-1 done with 100/1000
# ForkPoolWorker-1 done with 200/1000
# ForkPoolWorker-1 done with 300/1000
# ForkPoolWorker-1 done with 400/1000
# ForkPoolWorker-1 done with 500/1000
# ForkPoolWorker-1 done with 600/1000
# ForkPoolWorker-1 done with 700/1000
# ForkPoolWorker-1 done with 800/1000
# ForkPoolWorker-1 done with 900/1000
# ForkPoolWorker-1 done with 1000/1000
# New Average score is 0.32+-0.10
# Number of different identity is 111
# Different percent is 0.11
# Mischief managed in 991.5039012432098s

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.5/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.5/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.5/inference_metricsoriginal
# Running on 1000 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 1000 images
# ForkPoolWorker-1 done with 100/1000
# ForkPoolWorker-1 done with 200/1000
# ForkPoolWorker-1 done with 300/1000
# ForkPoolWorker-1 done with 400/1000
# ForkPoolWorker-1 done with 500/1000
# ForkPoolWorker-1 done with 600/1000
# ForkPoolWorker-1 done with 700/1000
# ForkPoolWorker-1 done with 800/1000
# ForkPoolWorker-1 done with 900/1000
# ForkPoolWorker-1 done with 1000/1000
# New Average score is 0.39+-0.11
# Number of different identity is 42
# Different percent is 0.04
# Mischief managed in 990.560136795044s

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.6/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.6/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.6/inference_metricsoriginal
# Running on 1000 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 1000 images
# ForkPoolWorker-1 done with 100/1000
# ForkPoolWorker-1 done with 200/1000
# ForkPoolWorker-1 done with 300/1000
# ForkPoolWorker-1 done with 400/1000
# ForkPoolWorker-1 done with 500/1000
# ForkPoolWorker-1 done with 600/1000
# ForkPoolWorker-1 done with 700/1000
# ForkPoolWorker-1 done with 800/1000
# ForkPoolWorker-1 done with 900/1000
# ForkPoolWorker-1 done with 1000/1000
# New Average score is 0.44+-0.11
# Number of different identity is 24
# Different percent is 0.02
# Mischief managed in 999.6137924194336s

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.7/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.7/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.7/inference_metricsoriginal
# Running on 1000 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 1000 images
# ForkPoolWorker-1 done with 100/1000
# ForkPoolWorker-1 done with 200/1000
# ForkPoolWorker-1 done with 300/1000
# ForkPoolWorker-1 done with 400/1000
# ForkPoolWorker-1 done with 500/1000
# ForkPoolWorker-1 done with 600/1000
# ForkPoolWorker-1 done with 700/1000
# ForkPoolWorker-1 done with 800/1000
# ForkPoolWorker-1 done with 900/1000
# ForkPoolWorker-1 done with 1000/1000
# New Average score is 0.44+-0.12
# Number of different identity is 25
# Different percent is 0.03
# Mischief managed in 989.8195986747742s

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.8/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.8/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.8/inference_metricsoriginal
# Running on 1000 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 1000 images
# ForkPoolWorker-1 done with 100/1000
# ForkPoolWorker-1 done with 200/1000
# ForkPoolWorker-1 done with 300/1000
# ForkPoolWorker-1 done with 400/1000
# ForkPoolWorker-1 done with 500/1000
# ForkPoolWorker-1 done with 600/1000
# ForkPoolWorker-1 done with 700/1000
# ForkPoolWorker-1 done with 800/1000
# ForkPoolWorker-1 done with 900/1000
# ForkPoolWorker-1 done with 1000/1000
# New Average score is 0.28+-0.12
# Number of different identity is 222
# Different percent is 0.22
# Mischief managed in 993.4213247299194s

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.9/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.9/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.9/inference_metricsoriginal
# Traceback (most recent call last):
#   File "scripts/calc_id_loss_parallel.py", line 139, in <module>
#     run(args)
#   File "scripts/calc_id_loss_parallel.py", line 105, in run
#     file_chunks = list(chunks(file_paths, int(math.ceil(len(file_paths) / args.num_threads))))
#   File "scripts/calc_id_loss_parallel.py", line 24, in chunks
#     for i in range(0, len(lst), n):
# ValueError: range() arg 3 must not be zero

# %%
# Calculating ID similarity value between original images with CIAGAN output images

! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_1.0/original \
--gt_path=./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_1.0/generated \
--id_threhold=0.19

##The ID similarity between original and Output Images is: 
#Different percent is :
# Out:
# The inference metrics output path is ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_1.0/inference_metricsoriginal
# Running on 1000 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 1000 images
# ForkPoolWorker-1 done with 100/1000
# ForkPoolWorker-1 done with 200/1000
# ForkPoolWorker-1 done with 300/1000
# ForkPoolWorker-1 done with 400/1000
# ForkPoolWorker-1 done with 500/1000
# ForkPoolWorker-1 done with 600/1000
# ForkPoolWorker-1 done with 700/1000
# ForkPoolWorker-1 done with 800/1000
# ForkPoolWorker-1 done with 900/1000
# ForkPoolWorker-1 done with 1000/1000
# New Average score is 0.50+-0.12
# Number of different identity is 21
# Different percent is 0.02
# Traceback (most recent call last):
#   File "scripts/calc_id_loss_parallel.py", line 139, in <module>
#     run(args)
#   File "scripts/calc_id_loss_parallel.py", line 128, in run
#     with open(os.path.join(out_path, 'stat_id.txt'), 'w') as f:
# ...

# %% [markdown]
# # Inference FFHQ
# #### Calculating ID similarity value between original images with inferenced output images
#
# *   ***Privacy 0.0 ID similarity: 0.10+-0.08***
# *   Privacy 0.1 ID similarity: 0.13+-0.08
# *   Privacy 0.2 ID similarity: 0.16+-0.08
# *   ***Privacy 0.3 ID similarity: 0.22+-0.09***
# *   Privacy 0.4 ID similarity: 0.27+-0.09
# *   Privacy 0.5 ID similarity: 0.33+-0.10
# *   ***Privacy 0.6 ID similarity: 0.42+-0.10***
# *   Privacy 0.7 ID similarity: 0.49+-0.11
# *   Privacy 0.8 ID similarity: 0.57+-0.11
# *   ***Privacy 0.9 ID similarity: 0.62+-0.11***
# *   Privacy 1.0 ID similarity: 0.63+-0.11

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.0 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.0 ID similarity: 0.06+-0.07
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.0  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.0 ID similarity: 0.10+-0.08
#Different percent is 0.89
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.0
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.10+-0.08
# Number of different identity is 884
# Different percent is 0.89
# Mischief managed in 53.792564868927s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.1 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.1 ID similarity: 0.09+-0.08
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.1  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.1 ID similarity: 0.13+-0.08
#Different percent is 0.77
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.1
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.13+-0.08
# Number of different identity is 770
# Different percent is 0.77
# Mischief managed in 582.0961463451385s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.2 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.2 ID similarity: 0.13+-0.09
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.2  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.2 ID similarity: 0.16+-0.08
#Different percent is 0.64
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.2
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.16+-0.08
# Number of different identity is 638
# Different percent is 0.64
# Mischief managed in 569.2857148647308s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.3 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.3 ID similarity: 0.17+-0.10
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.3  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.3 ID similarity: 0.22+-0.09
#Different percent is 0.38
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.3
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.22+-0.09
# Number of different identity is 380
# Different percent is 0.38
# Mischief managed in 576.5436053276062s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.4 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.4 ID similarity: 0.22+-0.10
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.4  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.4 ID similarity: 0.27+-0.09
#Different percent is 0.18
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.4
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.27+-0.09
# Number of different identity is 176
# Different percent is 0.18
# Mischief managed in 590.1285662651062s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.5 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.5 ID similarity: 0.27+-0.11
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.5  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.5 ID similarity: 0.33+-0.10
#Different percent is 0.07
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.5
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.33+-0.10
# Number of different identity is 74
# Different percent is 0.07
# Mischief managed in 580.5254418849945s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.6 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.6 ID similarity: 0.30+-0.11
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.6 \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.6 ID similarity: 0.42+-0.10
#Different percent is 0.02
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.6
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.42+-0.10
# Number of different identity is 24
# Different percent is 0.02
# Mischief managed in 584.8386538028717s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.7 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.7 ID similarity: 0.36+-0.12
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.7  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.7 ID similarity: 0.49+-0.11
#Different percent is 0.02
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.7
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.49+-0.11
# Number of different identity is 16
# Different percent is 0.02
# Mischief managed in 577.1232223510742s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.8 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.8 ID similarity: 0.38+-0.12
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.8  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.8 ID similarity: 0.57+-0.11
#Different percent is 0.01
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.8
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.57+-0.11
# Number of different identity is 13
# Different percent is 0.01
# Mischief managed in 589.5566065311432s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_0.9 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 0.9 ID similarity: 0.38+-0.12
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.9  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 0.9 ID similarity: 0.62+-0.11
#Different percent is 0.01
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics0.9
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.62+-0.11
# Number of different identity is 14
# Different percent is 0.01
# Mischief managed in 384.2599387168884s

# %%
"""# Calculating ID similarity value between original images with inferenced output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results_privacy_1.0 \
--gt_path=./image_datasets/ffhq5k_6k_aligned
#Privacy 1.0 ID similarity: 0.38+-0.13
"""
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_1.0  \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--id_threhold=0.19
#Privacy 1.0 ID similarity: 0.63+-0.11
#Different percent is 0.02
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/inference_metrics1.0
# Running on 998 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 998 images
# ForkPoolWorker-1 done with 100/998
# ForkPoolWorker-1 done with 200/998
# ForkPoolWorker-1 done with 300/998
# ForkPoolWorker-1 done with 400/998
# ForkPoolWorker-1 done with 500/998
# ForkPoolWorker-1 done with 600/998
# ForkPoolWorker-1 done with 700/998
# ForkPoolWorker-1 done with 800/998
# ForkPoolWorker-1 done with 900/998
# New Average score is 0.63+-0.11
# Number of different identity is 15
# Different percent is 0.02
# Mischief managed in 386.2583565711975s

# %%
#Different percent is 0.89
#Different percent is 0.77
#Different percent is 0.64
#Different percent is 0.38
#Different percent is 0.18
#Different percent is 0.07
#Different percent is 0.02
#Different percent is 0.02
#Different percent is 0.01
#Different percent is 0.01
#Different percent is 0.02

# %% [markdown]
# # Blurred
# #### Calculating ID similarity value between original images with blurred images
#
# * ***ksize=349 ID similarity: 0.10+-0.08***
# * ksize=149 ID similarity:
# * ksize=099 ID similarity:
# * ksize=069 ID similarity:
# * ksize=065 ID similarity: 0.18+-0.10
# * ***ksize=059 ID similarity: 0.21+-0.10***
# * ksize=055 ID similarity:
# * ksize=049 ID similarity:
# * ksize=045 ID similarity:
# * ***ksize=043 ID similarity: 0.38+-0.11***
# * ***ksize=039 ID similarity: 0.44+-0.11***
# * ksize=035 ID similarity:
# * ksize=033 ID similarity: 0.55+-0.10
# * ***ksize=031 ID similarity: 0.58+-0.10***
# * ksize=029 ID similarity:
# * ksize=009 ID similarity:

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_349/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_349/ffhq5k_6k_blurred_ori
#ksize=349 ID similarity: 0.10+-0.08"""
# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred_ori \
--id_threhold=0.19
#ksize=349 ID similarity: 0.10+-0.08
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/inference_metricsblurred
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.10+-0.08
# Number of different identity is 884
# Different percent is 0.89
# Mischief managed in 839.6747364997864s

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_149/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_149/ffhq5k_6k_blurred_ori
#ksize=149 ID similarity: 0.11+-0.08"""
# Out:
# '# Calculating ID similarity value between original images with blurred images\n! python scripts/calc_id_loss_parallel.py --num_threads=1 --data_path=./image_datasets/ffhq5k_6k_blurred_ksize_149/ffhq5k_6k_blurred --gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_149/ffhq5k_6k_blurred_ori\n#ksize=149 ID similarity: 0.11+-0.08'

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_099/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_099/ffhq5k_6k_blurred_ori
#ksize=099 ID similarity: 0.12+-0.09"""
# Out:
# '# Calculating ID similarity value between original images with blurred images\n! python scripts/calc_id_loss_parallel.py --num_threads=1 --data_path=./image_datasets/ffhq5k_6k_blurred_ksize_099/ffhq5k_6k_blurred --gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_099/ffhq5k_6k_blurred_ori\n#ksize=099 ID similarity: 0.12+-0.09'

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_069/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_069/ffhq5k_6k_blurred_ori
#ksize=069 ID similarity: 0.16+-0.10"""
# Out:
# '# Calculating ID similarity value between original images with blurred images\n! python scripts/calc_id_loss_parallel.py --num_threads=1 --data_path=./image_datasets/ffhq5k_6k_blurred_ksize_069/ffhq5k_6k_blurred --gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_069/ffhq5k_6k_blurred_ori\n#ksize=069 ID similarity: 0.16+-0.10'

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_065/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_065/ffhq5k_6k_blurred_ori
#ksize=065 ID similarity: 0.18+-0.10"""
# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred_ori \
--id_threhold=0.19
#ksize=065 ID similarity: 0.18+-0.09
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/inference_metricsblurred
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.18+-0.09
# Number of different identity is 570
# Different percent is 0.58
# Mischief managed in 816.7865295410156s

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_059/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_059/ffhq5k_6k_blurred_ori
#ksize=059 ID similarity: 0.22+-0.11"""
# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred_ori \
--id_threhold=0.19
#ksize=059 ID similarity: 0.21+-0.10
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/inference_metricsblurred
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.21+-0.10
# Number of different identity is 409
# Different percent is 0.41
# Mischief managed in 817.7289459705353s

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_055/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_055/ffhq5k_6k_blurred_ori
#ksize=055 ID similarity: 0.25+-0.11"""
# Out:
# '# Calculating ID similarity value between original images with blurred images\n! python scripts/calc_id_loss_parallel.py --num_threads=1 --data_path=./image_datasets/ffhq5k_6k_blurred_ksize_055/ffhq5k_6k_blurred --gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_055/ffhq5k_6k_blurred_ori\n#ksize=055 ID similarity: 0.25+-0.11'

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_049/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_049/ffhq5k_6k_blurred_ori
#ksize=049 ID similarity: 0.28+-0.11"""
# Out:
# '# Calculating ID similarity value between original images with blurred images\n! python scripts/calc_id_loss_parallel.py --num_threads=1 --data_path=./image_datasets/ffhq5k_6k_blurred_ksize_049/ffhq5k_6k_blurred --gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_049/ffhq5k_6k_blurred_ori\n#ksize=049 ID similarity: 0.28+-0.11'

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_045/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_045/ffhq5k_6k_blurred_ori
#ksize=045 ID similarity: 0.35+-0.12"""
# Out:
# '# Calculating ID similarity value between original images with blurred images\n! python scripts/calc_id_loss_parallel.py --num_threads=1 --data_path=./image_datasets/ffhq5k_6k_blurred_ksize_045/ffhq5k_6k_blurred --gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_045/ffhq5k_6k_blurred_ori\n#ksize=045 ID similarity: 0.35+-0.12'

# %%
# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred_ori \
--id_threhold=0.19
#ksize=043 ID similarity: 0.38+-0.11
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/inference_metricsblurred
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.38+-0.11
# Number of different identity is 57
# Different percent is 0.06
# Mischief managed in 813.8925852775574s

# %%
# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred_ori \
--id_threhold=0.19
#ksize=039 ID similarity: 0.44+-0.11
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/inference_metricsblurred
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.44+-0.11
# Number of different identity is 23
# Different percent is 0.02
# Mischief managed in 817.8219103813171s

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_035/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_035/ffhq5k_6k_blurred_ori
#ksize=035 ID similarity: 0.51+-0.11"""

# %%
# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_033/ffhq10k_11k_blurred \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_033/ffhq10k_11k_blurred_ori \
--id_threhold=0.19
#ksize=033 ID similarity: 0.55+-0.10
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_033/inference_metricsblurred
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.55+-0.10
# Number of different identity is 3
# Different percent is 0.00
# Mischief managed in 831.6537024974823s

# %%
# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred_ori \
--id_threhold=0.19
#ksize=031 ID similarity: 0.58+-0.10
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/inference_metricsblurred
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.58+-0.10
# Number of different identity is 2
# Different percent is 0.00
# Mischief managed in 815.7612702846527s

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_029/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_029/ffhq5k_6k_blurred_ori
#ksize=029 ID similarity: 0.64+-0.10"""

# %%
"""# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_blurred_ksize_009/ffhq5k_6k_blurred \
--gt_path=./image_datasets/ffhq5k_6k_blurred_ksize_009/ffhq5k_6k_blurred_ori
#ksize=009 ID similarity: 0.97+-0.01"""

# %% [markdown]
# # Mosaiced
# ### Calculating ID similarity value between original images with mosaiced images
#
# * ***neighbor100 ID similarity: 0.12+-0.08***
# * ***neighbor80 ID similarity: 0.12+-0.08***
# * neighbor50 ID similarity:
# * neighbor25 ID similarity:
# * neighbor20 ID similarity:
# * neighbor18 ID similarity:
# * neighbor15 ID similarity:
# * ***neighbor13 ID similarity: 0.20+-0.10***
# * neighbor10 ID similarity:
# * ***neighbor09 ID similarity: 0.40+-0.11***
# * neighbor08 ID similarity:
# * ***neighbor07 ID similarity: 0.58+-0.10***
# * neighbor06 ID similarity: 0.66+-0.12
# * neighbor05 ID similarity: 0.78+-0.06
# * neighbor04 ID similarity: 0.87+-0.04

# %%
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor100 ID similarity: 0.12+-0.08
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/inference_metricsmosaiced
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.12+-0.08
# Number of different identity is 806
# Different percent is 0.82
# Mischief managed in 712.2568438053131s

# %%
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor80 ID similarity: 0.12+-0.08
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/inference_metricsmosaiced
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.12+-0.08
# Number of different identity is 797
# Different percent is 0.81
# Mischief managed in 711.8214678764343s

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor50/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor50/ffhq5k_6k_mosaiced_ori
#neighbor50 ID similarity: 0.13+-0.08"""
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor50/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor50/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor50 ID similarity:

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor25/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor25/ffhq5k_6k_mosaiced_ori
#neighbor25 ID similarity: 0.14+-0.08"""
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor25/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor25/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor25 ID similarity:

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor20/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor20/ffhq5k_6k_mosaiced_ori
#neighbor20 ID similarity: 0.14+-0.08"""
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor20/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor20/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor20 ID similarity:

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor18/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor18/ffhq5k_6k_mosaiced_ori
#neighbor18 ID similarity: 0.15+-0.09"""
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor18/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor18/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor18 ID similarity:

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor15/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor15/ffhq5k_6k_mosaiced_ori
#neighbor15 ID similarity: 0.16+-0.09"""
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor15/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor15/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor15 ID similarity:

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor13/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor13/ffhq5k_6k_mosaiced_ori
#neighbor13 ID similarity: 0.20+-0.10"""
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor13 ID similarity: 0.20+-0.10
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/inference_metricsmosaiced
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.20+-0.10
# Number of different identity is 485
# Different percent is 0.49
# Mischief managed in 716.1804180145264s

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor10/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor10/ffhq5k_6k_mosaiced_ori
#neighbor10 ID similarity: 0.34+-0.12"""
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor10/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor10/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor10 ID similarity:
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor10/inference_metricsmosaiced
# Traceback (most recent call last):
#   File "scripts/calc_id_loss_parallel.py", line 139, in <module>
#     run(args)
#   File "scripts/calc_id_loss_parallel.py", line 105, in run
#     file_chunks = list(chunks(file_paths, int(math.ceil(len(file_paths) / args.num_threads))))
#   File "scripts/calc_id_loss_parallel.py", line 24, in chunks
#     for i in range(0, len(lst), n):
# ValueError: range() arg 3 must not be zero

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor09/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor09/ffhq5k_6k_mosaiced_ori
#neighbor09 ID similarity: 0.41+-0.11"""
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor09 ID similarity: 0.40+-0.11
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/inference_metricsmosaiced
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.40+-0.11
# Number of different identity is 22
# Different percent is 0.02
# Mischief managed in 710.5069909095764s

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor08/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor08/ffhq5k_6k_mosaiced_ori
#neighbor08 ID similarity: 0.50+-0.10"""

# %%
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor07 ID similarity: 0.58+-0.10
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/inference_metricsmosaiced
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.58+-0.10
# Number of different identity is 1
# Different percent is 0.00
# Mischief managed in 895.8760106563568s

# %%
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor06/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor06/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor06 ID similarity: 0.66+-0.12
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor06/inference_metricsmosaiced
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.67+-0.08
# Number of different identity is 0
# Different percent is 0.00
# Mischief managed in 877.0001800060272s

# %%
"""# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor05/ffhq5k_6k_mosaiced \
--gt_path=./image_datasets/ffhq5k_6k_mosaiced_neighbor05/ffhq5k_6k_mosaiced_ori
#neighbor05 ID similarity: 0.78+-0.06"""

# %%
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced_ori \
--id_threhold=0.19
#neighbor04 ID similarity:
# Out:
# The inference metrics output path is ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/inference_metricsmosaiced
# Running on 988 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 988 images
# ForkPoolWorker-1 done with 100/988
# ForkPoolWorker-1 done with 200/988
# ForkPoolWorker-1 done with 300/988
# ForkPoolWorker-1 done with 400/988
# ForkPoolWorker-1 done with 500/988
# ForkPoolWorker-1 done with 600/988
# ForkPoolWorker-1 done with 700/988
# ForkPoolWorker-1 done with 800/988
# ForkPoolWorker-1 done with 900/988
# New Average score is 0.87+-0.04
# Number of different identity is 0
# Different percent is 0.00
# Mischief managed in 890.4376471042633s
