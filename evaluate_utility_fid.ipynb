# %%
from google.colab import drive
drive.mount('/content/drive')

import os 
os.chdir('/content/drive/My Drive/pSp_PrivacyEncoder')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/pSp_PrivacyEncoder
# Out:
# /content

# %% [markdown]
# # DeepPrivacy
#
#
# *   FID: 25.943295804448354

# %%
# Calculating FID value between aligned images with DeepPrivacy output images
! python pytorch_fid/fid_score.py \
/content/drive/MyDrive/Image_datasets/celeba_align_20k_21k_aligned ./image_datasets/DeepPrivacy_celeba_20k_21k_output/generated 
#The FID value between original and DeepPrivacy Output Images is:
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['/content/drive/MyDrive/Image_datasets/celeba_align_20k_21k_aligned', './image_datasets/DeepPrivacy_celeba_20k_21k_output/generated'])
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:01<00:00, 60.9MB/s]
# loading images from dir: /content/drive/MyDrive/Image_datasets/celeba_align_20k_21k_aligned
# 100% 20/20 [03:21<00:00, 10.06s/it]
# loading images from dir: image_datasets/DeepPrivacy_celeba_20k_21k_output/generated
# 100% 20/20 [03:17<00:00,  9.90s/it]
# FID:  25.943295804448354

# %% [markdown]
# # CIAGAN
#
#
# *   FID: 12.724999561982258

# %%
# Calculating FID value between aligned images with CIAGAN output images
! python pytorch_fid/fid_score.py \
./image_datasets/CIAGAN_celeba_20k_21k_output/original ./image_datasets/CIAGAN_celeba_20k_21k_output/generated 
#The FID value between original and CIAGAN Output Images is: 12.724999561982258
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/CIAGAN_celeba_20k_21k_output/original', './image_datasets/CIAGAN_celeba_20k_21k_output/generated'])
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:04<00:00, 21.3MB/s]
# loading images from dir: image_datasets/CIAGAN_celeba_20k_21k_output/original
# 100% 20/20 [05:51<00:00, 17.57s/it]
# loading images from dir: image_datasets/CIAGAN_celeba_20k_21k_output/generated
# 100% 20/20 [04:34<00:00, 13.70s/it]
# FID:  12.724999561982258

# %% [markdown]
# # Inference CelebA
#
# * Privacy 0.0 FID:
# * Privacy 0.1 FID:
# * Privacy 0.2 FID:  31.1058061077417
# * Privacy 0.3 FID:
# * Privacy 0.4 FID:
# * Privacy 0.5 FID:
# * Privacy 0.6 FID:
# * Privacy 0.7 FID:
# * Privacy 0.8 FID:
# * Privacy 0.9 FID:
# * Privacy 1.0 FID:

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.0/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.0/generated 
#The FID value between original and Output Images is:
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.0/original', './image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.0/generated'])
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:01<00:00, 65.2MB/s]
# loading images from dir: image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.0/original
# 100% 20/20 [02:01<00:00,  6.09s/it]
# loading images from dir: image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.0/generated
# 100% 20/20 [02:44<00:00,  8.24s/it]
# FID:  33.40859251240329

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.1/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.1/generated 
#The FID value between original and Output Images is:
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.1/original', './image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.1/generated'])
# loading images from dir: image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.1/original
# 100% 6/6 [00:32<00:00,  5.48s/it]
# loading images from dir: image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.1/generated
# 100% 6/6 [00:55<00:00,  9.27s/it]
# FID:  54.73020043744097

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.2/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.2/generated 
#The FID value between original and Output Images is:
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.2/original', './image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.2/generated'])
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:04<00:00, 21.9MB/s]
# loading images from dir: image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.2/original
# 100% 20/20 [04:59<00:00, 15.00s/it]
# loading images from dir: image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.2/generated
# 100% 20/20 [05:11<00:00, 15.58s/it]
# FID:  31.1058061077417

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.3/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.3/generated 
#The FID value between original and Output Images is:

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.4/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.4/generated 
#The FID value between original and Output Images is:

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.5/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.5/generated 
#The FID value between original and Output Images is: 56.96238492234028

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.6/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.6/generated 
#The FID value between original and Output Images is:

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.7/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.7/generated 
#The FID value between original and Output Images is:

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.8/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.8/generated 
#The FID value between original and Output Images is:

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.9/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_0.9/generated 
#The FID value between original and Output Images is:

# %%
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_1.0/original ./image_datasets/pSp_celeba_20k_21k_output/inference_results_privacy_1.0/generated 
#The FID value between original and Output Images is:

# %% [markdown]
# # Inference FFHQ
#
# * Privacy 0.0 FID:  48.51051346196209
# * Privacy 0.1 FID:  50.194949139686855
# * Privacy 0.2 FID:  48.99935652232807
# * Privacy 0.3 FID:  47.51895149263629
# * Privacy 0.4 FID:  48.68185554671959
# * Privacy 0.5 FID:  48.29441867188149
# * Privacy 0.6 FID:  46.33730801332146
# * Privacy 0.7 FID:  46.34938243786257
# * Privacy 0.8 FID:  47.396561657527
# * Privacy 0.9 FID:  47.703934563973206
# * Privacy 1.0 FID:  47.86317522472757

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.0 
#Privacy 0.0 FID:  70.4945598102683"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.0 
#Privacy 0.0 FID:  48.51051346196209
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.0'])
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:07<00:00, 13.2MB/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [04:24<00:00, 13.20s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.0
# 100% 20/20 [04:12<00:00, 12.60s/it]
# FID:  48.51051346196209

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.1 
#Privacy 0.1 FID:  73.66549065690481"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.1
#Privacy 0.1 FID:  50.194949139686855
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.1'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.99it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.1
# 100% 20/20 [04:15<00:00, 12.76s/it]
# FID:  50.194949139686855

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.2
#Privacy 0.2 FID:  69.28680708809162"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.2 
#Privacy 0.2 FID:  48.99935652232807
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.2'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.97it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.2
# 100% 20/20 [04:13<00:00, 12.68s/it]
# FID:  48.99935652232807

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.3
#Privacy 0.3 FID:  69.9404597012981"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.3 
#Privacy 0.3 FID:  47.51895149263629
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.3'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.95it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.3
# 100% 20/20 [04:12<00:00, 12.61s/it]
# FID:  47.51895149263629

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.4
#Privacy 0.4 FID:  66.91399359757901"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.4 
#Privacy 0.4 FID:  48.68185554671959
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.4'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.87it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.4
# 100% 20/20 [04:13<00:00, 12.67s/it]
# FID:  48.68185554671959

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.5
#Privacy 0.5 FID:  67.79517606725312"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.5 
#Privacy 0.5 FID:  48.29441867188149
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.5'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.88it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.5
# 100% 20/20 [04:14<00:00, 12.71s/it]
# FID:  48.29441867188149

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.6
#Privacy 0.6 FID:  70.2898211191849"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.6 
#Privacy 0.6 FID:  46.33730801332146
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.6'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.76it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.6
# 100% 20/20 [04:04<00:00, 12.22s/it]
# FID:  46.33730801332146

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.7 
#Privacy 0.7 FID:  67.06826100952802"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.7 
#Privacy 0.7 FID:  46.34938243786257
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.7'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.90it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.7
# 100% 20/20 [04:02<00:00, 12.15s/it]
# FID:  46.34938243786257

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.8
#Privacy 0.8 FID:  67.13009692080169"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.8 
#Privacy 0.8 FID:  47.396561657527
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.8'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.83it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.8
# 100% 20/20 [04:07<00:00, 12.37s/it]
# FID:  47.396561657527

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_0.9
#Privacy 0.9 FID:  67.334064250386"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.9 
#Privacy 0.9 FID:  47.703934563973206
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.9'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.81it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.9
# 100% 20/20 [04:03<00:00, 12.17s/it]
# FID:  47.703934563973206

# %%
"""# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_aligned ./image_datasets/inference_results_privacy_1.0
#Privacy 1.0 FID:  67.65130488493202"""
# Calculating FID value between aligned images with inferenced output images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_1.0 
#Privacy 1.0 FID:  47.86317522472757
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_1.0'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# 100% 20/20 [00:05<00:00,  3.89it/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_1.0
# 100% 20/20 [04:07<00:00, 12.36s/it]
# FID:  47.86317522472757

# %%
### ffhq10k_11k ###
#Privacy 0.0 FID:  48.51051346196209
#Privacy 0.1 FID:  50.194949139686855
#Privacy 0.2 FID:  48.99935652232807
#Privacy 0.3 FID:  47.51895149263629
#Privacy 0.4 FID:  48.68185554671959
#Privacy 0.5 FID:  48.29441867188149
#Privacy 0.6 FID:  46.33730801332146
#Privacy 0.7 FID:  46.34938243786257
#Privacy 0.8 FID:  47.396561657527
#Privacy 0.9 FID:  47.703934563973206
#Privacy 1.0 FID:  47.86317522472757

### ffhq5k_6k ###
#Privacy 0.0 FID:  70.4945598102683
#Privacy 0.1 FID:  73.66549065690481
#Privacy 0.2 FID:  69.28680708809162
#Privacy 0.3 FID:  69.9404597012981
#Privacy 0.4 FID:  66.91399359757901
#Privacy 0.5 FID:  67.79517606725312
#Privacy 0.6 FID:  70.2898211191849
#Privacy 0.7 FID:  67.06826100952802
#Privacy 0.8 FID:  67.13009692080169
#Privacy 0.9 FID:  67.334064250386
#Privacy 1.0 FID:  67.65130488493202

# %% [markdown]
# # Blurred
# Calculating FID value between aligned images with blurred images

# %%
"""# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_blurred_ksize_349/ffhq5k_6k_blurred_ori ./image_datasets/ffhq5k_6k_blurred_ksize_349/ffhq5k_6k_blurred 
#Blurring With Kernel Size=349 FID:  159.11597447886857
"""
# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred 
#Blurring With Kernel Size=349 FID:  158.23199113698743
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred'])
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:01<00:00, 87.2MB/s]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred_ori
# 100% 20/20 [02:28<00:00,  7.40s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred
# 100% 20/20 [01:27<00:00,  4.36s/it]
# FID:  158.23199113698743

# %%
"""# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_blurred_ksize_149/ffhq5k_6k_blurred_ori ./image_datasets/ffhq5k_6k_blurred_ksize_149/ffhq5k_6k_blurred 
#Blurring With Kernel Size=149 FID:  139.03735306423926
"""

# %%
"""# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_blurred_ksize_099/ffhq5k_6k_blurred_ori ./image_datasets/ffhq5k_6k_blurred_ksize_099/ffhq5k_6k_blurred 
#Blurring With Kernel Size=099 FID:  121.63250162791658
"""

# %%
"""# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_blurred_ksize_065/ffhq5k_6k_blurred_ori ./image_datasets/ffhq5k_6k_blurred_ksize_065/ffhq5k_6k_blurred 
#Blurring With Kernel Size=065 FID:  99.08775934780039
"""
# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred 
#Blurring With Kernel Size=065 FID:  98.6495631895732
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred_ori
# 100% 20/20 [01:21<00:00,  4.09s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred
# 100% 20/20 [01:28<00:00,  4.43s/it]
# FID:  98.6495631895732

# %%
# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred 
#Blurring With Kernel Size=059 FID:  88.00243580096168
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred_ori
# 100% 20/20 [01:18<00:00,  3.90s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred
# 100% 20/20 [01:16<00:00,  3.82s/it]
# FID:  88.00243580096168

# %%
"""# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_blurred_ksize_049/ffhq5k_6k_blurred_ori ./image_datasets/ffhq5k_6k_blurred_ksize_049/ffhq5k_6k_blurred 
#Blurring With Kernel Size=049 FID:  75.74916343832709
"""

# %%
# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred 
#Blurring With Kernel Size=043 FID:  65.82369909952422
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred_ori
# 100% 20/20 [01:19<00:00,  3.98s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred
# 100% 20/20 [01:14<00:00,  3.73s/it]
# FID:  65.82369909952422

# %%
"""# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_blurred_ksize_039/ffhq5k_6k_blurred_ori ./image_datasets/ffhq5k_6k_blurred_ksize_039/ffhq5k_6k_blurred 
#Blurring With Kernel Size=039 FID:  59.96427622055353
"""
# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred 
#Blurring With Kernel Size=039 FID:  59.81792557905027
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred_ori
# 100% 20/20 [01:20<00:00,  4.01s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred
# 100% 20/20 [01:33<00:00,  4.65s/it]
# FID:  59.81792557905027

# %%
# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred 
#Blurring With Kernel Size=031 FID:  48.83291931366671
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred_ori
# 100% 20/20 [01:19<00:00,  4.00s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred
# 100% 20/20 [01:14<00:00,  3.74s/it]
# FID:  48.83291931366671

# %%
"""# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_blurred_ksize_029/ffhq5k_6k_blurred_ori ./image_datasets/ffhq5k_6k_blurred_ksize_029/ffhq5k_6k_blurred 
#Blurring With Kernel Size=029 FID:  47.63903220746664
"""

# %%
"""# Calculating FID value between aligned images with blurred images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_blurred_ksize_009/ffhq5k_6k_blurred_ori ./image_datasets/ffhq5k_6k_blurred_ksize_009/ffhq5k_6k_blurred 
#Blurring With Kernel Size=009 FID:  22.78119113734232
"""

# %% [markdown]
# # Mosaiced
#
# Calculating FID value between aligned images with mosaiced images

# %%
# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced 
#Mosaicing With Neighbor=100 FID: 130.71221282795995
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced_ori
# 100% 20/20 [01:19<00:00,  3.98s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced
# 100% 20/20 [02:13<00:00,  6.65s/it]
# FID:  130.71221282795995

# %%
# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced 
#Mosaicing With Neighbor=80 FID:  131.17524905429562
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced_ori
# 100% 20/20 [01:20<00:00,  4.03s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced
# 100% 20/20 [02:11<00:00,  6.59s/it]
# FID:  131.17524905429562

# %%
"""# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_mosaiced_neighbor50/ffhq5k_6k_mosaiced_ori ./image_datasets/ffhq5k_6k_mosaiced_neighbor50/ffhq5k_6k_mosaiced 
#Mosaicing With Neighbor=50 FID:  133.34502279901113
"""

# %%
"""# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_mosaiced_neighbor25/ffhq5k_6k_mosaiced_ori ./image_datasets/ffhq5k_6k_mosaiced_neighbor25/ffhq5k_6k_mosaiced 
#Mosaicing With Neighbor=25 FID:  129.01323064784125
"""

# %%
"""# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_mosaiced_neighbor20/ffhq5k_6k_mosaiced_ori ./image_datasets/ffhq5k_6k_mosaiced_neighbor20/ffhq5k_6k_mosaiced 
#Mosaicing With Neighbor=20 FID:  123.98152181095676
"""

# %%
"""# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_mosaiced_neighbor15/ffhq5k_6k_mosaiced_ori ./image_datasets/ffhq5k_6k_mosaiced_neighbor15/ffhq5k_6k_mosaiced 
#Mosaicing With Neighbor=15 FID:  122.39257503311308
"""

# %%
"""# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_mosaiced_neighbor13/ffhq5k_6k_mosaiced_ori ./image_datasets/ffhq5k_6k_mosaiced_neighbor13/ffhq5k_6k_mosaiced 
#Mosaicing With Neighbor=13 FID:  119.68029250270496
"""
# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced 
#Mosaicing With Neighbor=13 FID:  119.99349283810801
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced_ori
# 100% 20/20 [01:20<00:00,  4.00s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced
# 100% 20/20 [02:17<00:00,  6.90s/it]
# FID:  119.99349283810801

# %%
"""# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_mosaiced_neighbor10/ffhq5k_6k_mosaiced_ori ./image_datasets/ffhq5k_6k_mosaiced_neighbor10/ffhq5k_6k_mosaiced 
#Mosaicing With Neighbor=10 FID:  117.6415652212956
"""

# %%
"""# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_mosaiced_neighbor09/ffhq5k_6k_mosaiced_ori ./image_datasets/ffhq5k_6k_mosaiced_neighbor09/ffhq5k_6k_mosaiced 
#Mosaicing With Neighbor=09 FID:  116.96880322580006
"""
# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced 
#Mosaicing With Neighbor=09 FID:  117.74186285476821
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced_ori
# 100% 20/20 [01:18<00:00,  3.93s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced
# 100% 20/20 [02:13<00:00,  6.65s/it]
# FID:  117.74186285476821

# %%
# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced 
#Mosaicing With Neighbor=07 FID:  108.02793706975626
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced_ori
# 100% 20/20 [01:22<00:00,  4.13s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced
# 100% 20/20 [02:36<00:00,  7.83s/it]
# FID:  108.02793706975626

# %%
"""# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq5k_6k_mosaiced_neighbor05/ffhq5k_6k_mosaiced_ori ./image_datasets/ffhq5k_6k_mosaiced_neighbor05/ffhq5k_6k_mosaiced 
#Mosaicing With Neighbor=05 FID:  86.29325245879485
"""

# %%
# Calculating FID value between aligned images with mosaiced images
! python pytorch_fid/fid_score.py \
./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced_ori ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced 
#Mosaicing With Neighbor=04 FID:  55.38683069572937
# Out:
# Input arguments are:
#   Namespace(batch_size=50, device=None, dims=2048, path=['./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced_ori', './image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced'])
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced_ori
# 100% 20/20 [01:20<00:00,  4.00s/it]
# loading images from dir: image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced
# 100% 20/20 [02:54<00:00,  8.74s/it]
# FID:  55.38683069572937
