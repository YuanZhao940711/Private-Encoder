# %%
from google.colab import drive
drive.mount('/content/drive')

import os 
os.chdir('/content/drive/My Drive/pSp_PrivacyEncoder')
# Out:
# Mounted at /content/drive

# %%
#! wget http://arunponnusamy.com/files/mmod_human_face_detector.dat

# %%
# %cd /content/drive/My Drive/pSp_PrivacyEncoder
# Out:
# /content

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned

# %% [markdown]
# # CIAGAN

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/CIAGAN_celeba_20k_21k_output
# Out:
# Load 976 images
# 100% 976/976 [04:43<00:00,  3.45it/s]
#
# The CNN-based detected model finds 0.9939 percent faces
# from dataset: ./image_datasets/CIAGAN_celeba_20k_21k_output

# %% [markdown]
# # Blurred

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred
# Out:
# Load 988 images
# 100% 988/988 [03:27<00:00,  4.75it/s]
#
# The CNN-based detected model finds 0.7834 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_031/ffhq10k_11k_blurred

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_033/ffhq10k_11k_blurred
# Out:
# Load 988 images
# 100% 988/988 [03:06<00:00,  5.29it/s]
#
# The CNN-based detected model finds 0.7419 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_033/ffhq10k_11k_blurred

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred
# Out:
# Load 988 images
# 100% 988/988 [03:10<00:00,  5.18it/s]
#
# The CNN-based detected model finds 0.5597 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_039/ffhq10k_11k_blurred

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred
# Out:
# Load 988 images
# 100% 988/988 [02:58<00:00,  5.53it/s]
#
# The CNN-based detected model finds 0.4575 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_043/ffhq10k_11k_blurred

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred
# Out:
# Load 988 images
# 100% 988/988 [03:00<00:00,  5.49it/s]
#
# The CNN-based detected model finds 0.1457 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_059/ffhq10k_11k_blurred

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred
# Out:
# Load 988 images
# 100% 988/988 [02:57<00:00,  5.57it/s]
#
# The CNN-based detected model finds 0.0891 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_065/ffhq10k_11k_blurred

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred
# Out:
# Load 988 images
# 100% 988/988 [03:00<00:00,  5.47it/s]
#
# The CNN-based detected model finds 0.0020 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_blurred_ksize_349/ffhq10k_11k_blurred

# %% [markdown]
# # Inferenced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.0
# Out:
# Load 998 images
# 100% 998/998 [04:08<00:00,  4.01it/s]
#
# The CNN-based detected model finds 0.9990 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.0

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.1
# Out:
# Load 998 images
# 100% 998/998 [04:17<00:00,  3.87it/s]
#
# The CNN-based detected model finds 1.0010 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.1

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.2
# Out:
# Load 998 images
# 100% 998/998 [04:08<00:00,  4.01it/s]
#
# The CNN-based detected model finds 1.0010 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.2

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.3
# Out:
# Load 998 images
# 100% 998/998 [04:21<00:00,  3.81it/s]
#
# The CNN-based detected model finds 1.0020 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.3

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.4
# Out:
# Load 998 images
# 100% 998/998 [04:25<00:00,  3.76it/s]
#
# The CNN-based detected model finds 1.0010 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.4

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.5
# Out:
# Load 998 images
# 100% 998/998 [04:21<00:00,  3.81it/s]
#
# The CNN-based detected model finds 1.0020 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.5

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.6
# Out:
# Load 998 images
# 100% 998/998 [04:13<00:00,  3.94it/s]
#
# The CNN-based detected model finds 1.0030 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.6

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.7
# Out:
# Load 998 images
# 100% 998/998 [04:06<00:00,  4.04it/s]
#
# The CNN-based detected model finds 1.0030 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.7

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.8
# Out:
# Load 998 images
# 100% 998/998 [04:16<00:00,  3.89it/s]
#
# The CNN-based detected model finds 1.0020 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.8

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.9
# Out:
# Load 998 images
# 100% 998/998 [04:05<00:00,  4.06it/s]
#
# The CNN-based detected model finds 1.0060 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_0.9

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_1.0
# Out:
# Load 998 images
# 100% 998/998 [04:08<00:00,  4.01it/s]
#
# The CNN-based detected model finds 1.0020 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_inference_results_privacy_1.0

# %% [markdown]
# # Mosaiced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor03/ffhq10k_11k_mosaiced
# Out:
# Load 988 images
# 100% 988/988 [04:29<00:00,  3.67it/s]
#
# The CNN-based detected model finds 0.9980 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor03/ffhq10k_11k_mosaiced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced
# Out:
# Load 988 images
# 100% 988/988 [04:11<00:00,  3.92it/s]
#
# The CNN-based detected model finds 0.9970 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor04/ffhq10k_11k_mosaiced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor05/ffhq10k_11k_mosaiced
# Out:
# Load 988 images
# 100% 988/988 [04:04<00:00,  4.04it/s]
#
# The CNN-based detected model finds 0.9818 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor05/ffhq10k_11k_mosaiced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor06/ffhq10k_11k_mosaiced
# Out:
# Load 988 images
# 100% 988/988 [04:12<00:00,  3.91it/s]
#
# The CNN-based detected model finds 0.9696 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor06/ffhq10k_11k_mosaiced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced
# Out:
# Load 988 images
# 100% 988/988 [04:15<00:00,  3.86it/s]
#
# The CNN-based detected model finds 0.9403 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor07/ffhq10k_11k_mosaiced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced
# Out:
# Load 988 images
# 100% 988/988 [04:19<00:00,  3.81it/s]
#
# The CNN-based detected model finds 0.8188 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor09/ffhq10k_11k_mosaiced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor10/ffhq10k_11k_mosaiced
# Out:
# Load 0 images
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "scripts/face_detect.py", line 75, in <module>
#     print('\nThe {}-based detected model finds {:.4f} percent faces \nfrom dataset: {}'.format(args.model, face_num/img_num, args.input_dir))
# ZeroDivisionError: division by zero

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced
# Out:
# Load 988 images
# 100% 988/988 [06:14<00:00,  2.64it/s]
#
# The CNN-based detected model finds 0.0020 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor100/ffhq10k_11k_mosaiced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced
# Out:
# Load 988 images
# 100% 988/988 [06:01<00:00,  2.73it/s]
#
# The CNN-based detected model finds 0.4332 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor13/ffhq10k_11k_mosaiced

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor15/ffhq10k_11k_mosaiced
# Out:
# Load 0 images
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "scripts/face_detect.py", line 75, in <module>
#     print('\nThe {}-based detected model finds {:.4f} percent faces \nfrom dataset: {}'.format(args.model, face_num/img_num, args.input_dir))
# ZeroDivisionError: division by zero

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor18/ffhq10k_11k_mosaiced
# Out:
# Load 0 images
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "scripts/face_detect.py", line 75, in <module>
#     print('\nThe {}-based detected model finds {:.4f} percent faces \nfrom dataset: {}'.format(args.model, face_num/img_num, args.input_dir))
# ZeroDivisionError: division by zero

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor20/ffhq10k_11k_mosaiced
# Out:
# Load 0 images
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "scripts/face_detect.py", line 75, in <module>
#     print('\nThe {}-based detected model finds {:.4f} percent faces \nfrom dataset: {}'.format(args.model, face_num/img_num, args.input_dir))
# ZeroDivisionError: division by zero

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor25/ffhq10k_11k_mosaiced
# Out:
# Load 0 images
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "scripts/face_detect.py", line 75, in <module>
#     print('\nThe {}-based detected model finds {:.4f} percent faces \nfrom dataset: {}'.format(args.model, face_num/img_num, args.input_dir))
# ZeroDivisionError: division by zero

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor50/ffhq10k_11k_mosaiced
# Out:
# Load 0 images
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "scripts/face_detect.py", line 75, in <module>
#     print('\nThe {}-based detected model finds {:.4f} percent faces \nfrom dataset: {}'.format(args.model, face_num/img_num, args.input_dir))
# ZeroDivisionError: division by zero

# %%
! python scripts/face_detect.py \
--model=CNN \
--input_dir=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced
# Out:
# Load 988 images
# 100% 988/988 [06:01<00:00,  2.74it/s]
#
# The CNN-based detected model finds 0.0020 percent faces
# from dataset: ./image_datasets/ffhq10k_11k_related/ffhq10k_11k_mosaiced_neighbor80/ffhq10k_11k_mosaiced
