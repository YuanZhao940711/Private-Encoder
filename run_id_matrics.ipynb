# %%
from google.colab import drive
drive.mount('/content/drive')

import os 
os.chdir('/content/drive/My Drive/pSp_self_customize')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/pSp_self_customize
# Out:
# /content

# %%
# Calculating ID similarity value between original images with pSp output images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/inference_results \
--gt_path=./image_datasets/ffhq0k_5k
# ID similarity: 0.27+-0.09
# Out:
# Running on 5000 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 5000 images
# ForkPoolWorker-1 done with 100/5000
# ForkPoolWorker-1 done with 200/5000
# ForkPoolWorker-1 done with 300/5000
# ForkPoolWorker-1 done with 400/5000
# ForkPoolWorker-1 done with 500/5000
# ForkPoolWorker-1 done with 600/5000
# ForkPoolWorker-1 done with 700/5000
# ForkPoolWorker-1 done with 800/5000
# ForkPoolWorker-1 done with 900/5000
# ForkPoolWorker-1 done with 1000/5000
# ForkPoolWorker-1 done with 1100/5000
# ForkPoolWorker-1 done with 1200/5000
# ForkPoolWorker-1 done with 1300/5000
# ForkPoolWorker-1 done with 1400/5000
# ForkPoolWorker-1 done with 1500/5000
# ForkPoolWorker-1 done with 1600/5000
# ForkPoolWorker-1 done with 1700/5000
# ForkPoolWorker-1 done with 1800/5000
# ForkPoolWorker-1 done with 1900/5000
# ForkPoolWorker-1 done with 2000/5000
# ForkPoolWorker-1 done with 2100/5000
# ForkPoolWorker-1 done with 2200/5000
# ForkPoolWorker-1 done with 2300/5000
# ...

# %%
# Calculating ID similarity value between original images with blurred images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/blurred_pro_images \
--gt_path=./image_datasets/blurred_ori_images \
# ID similarity: 0.72+-0.09
# Out:
# Running on 4985 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 4985 images
# ForkPoolWorker-1 done with 100/4985
# ForkPoolWorker-1 done with 200/4985
# ForkPoolWorker-1 done with 300/4985
# ForkPoolWorker-1 done with 400/4985
# ForkPoolWorker-1 done with 500/4985
# ForkPoolWorker-1 done with 600/4985
# ForkPoolWorker-1 done with 700/4985
# ForkPoolWorker-1 done with 800/4985
# ForkPoolWorker-1 done with 900/4985
# ForkPoolWorker-1 done with 1000/4985
# ForkPoolWorker-1 done with 1100/4985
# ForkPoolWorker-1 done with 1200/4985
# ForkPoolWorker-1 done with 1300/4985
# ForkPoolWorker-1 done with 1400/4985
# ForkPoolWorker-1 done with 1500/4985
# ForkPoolWorker-1 done with 1600/4985
# ForkPoolWorker-1 done with 1700/4985
# ForkPoolWorker-1 done with 1800/4985
# ForkPoolWorker-1 done with 1900/4985
# ForkPoolWorker-1 done with 2000/4985
# ForkPoolWorker-1 done with 2100/4985
# ForkPoolWorker-1 done with 2200/4985
# ForkPoolWorker-1 done with 2300/4985
# ...

# %%
# Calculating ID similarity value between original images with mosaiced images
! python scripts/calc_id_loss_parallel.py \
--num_threads=1 \
--data_path=./image_datasets/mosaiced_pro_images \
--gt_path=./image_datasets/mosaiced_ori_images \
# ID similarity: 0.82+-0.06
# Out:
# Running on 4986 paths
# Here we goooo
# cuda:0
# 	ForkPoolWorker-1 is starting to extract on 4986 images
# ForkPoolWorker-1 done with 100/4986
# ForkPoolWorker-1 done with 200/4986
# ForkPoolWorker-1 done with 300/4986
# ForkPoolWorker-1 done with 400/4986
# ForkPoolWorker-1 done with 500/4986
# ForkPoolWorker-1 done with 600/4986
# ForkPoolWorker-1 done with 700/4986
# ForkPoolWorker-1 done with 800/4986
# ForkPoolWorker-1 done with 900/4986
# ForkPoolWorker-1 done with 1000/4986
# ForkPoolWorker-1 done with 1100/4986
# ForkPoolWorker-1 done with 1200/4986
# ForkPoolWorker-1 done with 1300/4986
# ForkPoolWorker-1 done with 1400/4986
# ForkPoolWorker-1 done with 1500/4986
# ForkPoolWorker-1 done with 1600/4986
# ForkPoolWorker-1 done with 1700/4986
# ForkPoolWorker-1 done with 1800/4986
# ForkPoolWorker-1 done with 1900/4986
# ForkPoolWorker-1 done with 2000/4986
# ForkPoolWorker-1 done with 2100/4986
# ForkPoolWorker-1 done with 2200/4986
# ForkPoolWorker-1 done with 2300/4986
# ...
