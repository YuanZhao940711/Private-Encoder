# %%
from google.colab import drive
drive.mount('/content/drive')

import os 
os.chdir('/content/drive/My Drive/pSp_self_customize')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/pSp_self_customize
# Out:
# /content

# %%
! python scripts/calc_id_loss.py \
--num_threads=1 \
--data_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned \
--gt_path=./image_datasets/ffhq10k_11k_related/ffhq10k_11k_aligned
# ID threshold: 0.19+-0.00
# Out:
# Running on 998 paths
# Here we goooo
# cuda:0
# 	MainProcess is starting to extract on 998 images
# MainProcess done with 100/998
# MainProcess done with 200/998
# MainProcess done with 300/998
# MainProcess done with 400/998
# MainProcess done with 500/998
# MainProcess done with 600/998
# MainProcess done with 700/998
# MainProcess done with 800/998
# MainProcess done with 900/998
# New Maximum score is 0.19+-0.00
# Mischief managed in 22754.6383330822s
